# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhilaaj/Machine_Learning/blob/main/Insurance_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9018c510-f186-4622-a658-28ea5ddd4ed0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9018c510-f186-4622-a658-28ea5ddd4ed0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
insurance=pd.read_csv('new_insurance_data[1].csv')

# %%
insurance.tail(5)
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 1333     1091267.0           170380500.5                              2.0
# 1334     1107872.0           201515184.8                              2.0
# 1335     1092005.0           223644981.3                              2.0
# 1336     1106821.0           252892382.6                              3.0
# 1337     1100328.0           261631699.3                              3.0
#
#       Anual_Salary     region      charges
# ...

# %%
insurance.shape
# Out:
# (1338, 13)

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
insurance.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
col=list(insurance.columns)
col
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %%
insurance['smoker'].mode()[0]
# Out:
# 'no'

# %%
insurance['age'].mean()
# Out:
# 39.31000752445448

# %%
insurance['age'].mean()
# Out:
# 39.31000752445448

# %%
for c1 in insurance.columns:
    if insurance[c1].dtype == 'object':
        mode_value = insurance[c1].mode()
        insurance[c1].fillna(mode_value, inplace=True)
    else:
      mean_value=insurance[c1].mean()
      insurance[c1].fillna(mean_value, inplace=True)

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1338 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1338 non-null   float64
#  3   children                         1338 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1338 non-null   float64
#  6   past_consultations               1338 non-null   float64
#  7   num_of_steps                     1338 non-null   float64
#  8   Hospital_expenditure             1338 non-null   float64
#  9   NUmber_of_past_hospitalizations  1338 non-null   float64
#  10  Anual_Salary                     1338 non-null   float64
# ...

# %%
insurance.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
insurance.shape
# Out:
# (1338, 13)

# %% [markdown]
# 1. Age:
#    - What is the distribution of age in the dataset? Are there any outliers?
#    - How does age correlate with other variables, such as BMI or claim amount?
#
# 2. Sex:
#    - What is the distribution of gender in the dataset? Are there more males or females?
#    - How does gender relate to variables like BMI, claim amount, or charges?
#
# 3. BMI:
#    - What is the distribution of BMI values? Are there any outliers?
#    - How does BMI correlate with other variables, such as age, claim amount, or hospital expenditure?
#
# 4. Children:
#    - How many children do most individuals in the dataset have? Is there any variation?
#    - How does the number of children impact variables like claim amount or charges?
#
# 5. Smoker:
#    - What proportion of individuals in the dataset are smokers?
#    - How does smoking status relate to variables like claim amount, hospital expenditure, or charges?
#
# 6. Claim_Amount:
#    - What is the distribution of claim amounts? Are there any extreme values?
#    - How do different factors like age, BMI, or smoking status impact the claim amount?
#
# 7. Past_Consultations:
#    - What is the average number of past consultations for individuals in the dataset?
#    - How does the number of past consultations correlate with other variables, such as claim amount or charges?
#
# 8. Num_of_Steps:
#    - What is the distribution of the number of steps taken by individuals?
#    - Is there any correlation between the number of steps and variables like BMI or charges?
#
# 9. Hospital_Expenditure:
#    - What is the range and distribution of hospital expenditure?
#    - How does hospital expenditure relate to other variables, such as claim amount or charges?
#
# 10. Number_of_Past_Hospitalizations:
#     - How many past hospitalizations have individuals had on average? Is there any pattern?
#     - Is there any relationship between the number of past hospitalizations and variables like claim amount or charges?
#
# 11. Annual_Salary:
#     - What is the distribution of annual salaries in the dataset?
#     - How does annual salary relate to variables like age, region, or charges?
#
# 12. Region:
#     - How is the dataset distributed based on regions? Which region has the highest representation?
#     - How does the region impact variables like claim amount or charges?
#
# 13. Charges:
#     - What is the distribution of charges? Are there any significant variations?
#     - How do charges relate to other variables like age, BMI, or claim amount?

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# 1. Distribution of Age
sns.histplot(insurance['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()

# %%
gender_counts = insurance['sex'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')#autopct: This parameter is used to format the percentages displayed on each wedge of the pie chart. The %1.1f%% format string specifies that the percentages should be displayed with one digit after the decimal point and followed by the percentage symbol (%).
plt.title('Distribution of Gender')
plt.show()

# %%
plt.boxplot(insurance['bmi'])
plt.title('Distribution of BMI')
plt.show()

# %%
sns.histplot(insurance['children'])
plt.xlabel('childrens')
# Out:
# Text(0.5, 0, 'childrens')

# %%
vc=insurance['smoker'].value_counts()
plt.pie(vc,labels=vc.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7faa5f2ba350>,
# ...
#  [Text(-0.8801026332278259, 0.6598631335250117, 'no'),
#   Text(0.8801026332278258, -0.6598631335250118, 'yes')],
#  [Text(-0.48005598176063224, 0.3599253455590972, '79.5%'),
#   Text(0.48005598176063213, -0.3599253455590973, '20.5%')])

# %%
sns.histplot(insurance['Claim_Amount'])
# Out:
# <Axes: xlabel='Claim_Amount', ylabel='Count'>

# %%
print(f'average past consultations ',insurance.past_consultations.mean())
# Out:
# average past consultations  15.216216216216218

# %%
sns.histplot(insurance['num_of_steps'], kde=True)
plt.xlabel('Number of Steps')
plt.ylabel('Count')
plt.title('Distribution of Number of Steps')
plt.show()

# %%
# 9. Distribution of Hospital Expenditure
sns.histplot(insurance['Hospital_expenditure'], kde=True)
plt.xlabel('Hospital Expenditure')
plt.ylabel('Count')
plt.title('Distribution of Hospital Expenditure')
plt.show()

# 10. Average Number of Past Hospitalizations
avg_hospitalizations = insurance['NUmber_of_past_hospitalizations'].mean()
print('Average Number of Past Hospitalizations:', avg_hospitalizations)

# 11. Distribution of Annual Salary
sns.histplot(insurance['Anual_Salary'], kde=True)
plt.xlabel('Annual Salary')
plt.ylabel('Count')
plt.title('Distribution of Annual Salary')
plt.show()

# 12. Distribution of Regions
sns.countplot(data=insurance, x='region')

plt.show()

# 13. Distribution of Charges
sns.histplot(insurance['charges'], kde=True)
plt.xlabel('Charges')
plt.ylabel('Count')
plt.title('Distribution of Charges')
plt.show()
# Out:
# Average Number of Past Hospitalizations: 1.06062874251497

# %%
correlation_matrix = insurance.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-116-574b5d0eab23>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = insurance.corr()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

df=insurance
# Split the data into features and target variable
X = df[['age', 'bmi', 'smoker']]
y = df['charges']

# Perform one-hot encoding for categorical variable 'smoker'
X = pd.get_dummies(X, columns=['smoker'], drop_first=True)

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize and fit the Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# Make predictions on the test set using Linear Regression
y_pred_linear = linear_model.predict(X_test)

# Evaluate Linear Regression model
mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)

print('Linear Regression Results:')
print('Mean Squared Error:', mse_linear)
print('R-squared:', r2_linear)

# Initialize and fit the Random Forest Regression model
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions on the test set using Random Forest Regression
y_pred_rf = rf_model.predict(X_test)

# Evaluate Random Forest Regression model
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print('\nRandom Forest Regression Results:')
print('Mean Squared Error:', mse_rf)
print('R-squared:', r2_rf)

# Initialize and fit the Support Vector Regression model
svr_model = SVR()
svr_model.fit(X_train, y_train)

# Make predictions on the test set using Support Vector Regression
y_pred_svr = svr_model.predict(X_test)

# Evaluate Support Vector Regression model
mse_svr = mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)

print('\nSupport Vector Regression Results:')
print('Mean Squared Error:', mse_svr)
print('R-squared:', r2_svr)

# Initialize and fit the Neural Network Regression model
nn_model = MLPRegressor(random_state=42)
nn_model.fit(X_train, y_train)

# Make predictions on the test set using Neural Network Regression
y_pred_nn = nn_model.predict(X_test)

# Evaluate Neural Network Regression model
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print('\nNeural Network Regression Results:')
print('Mean Squared Error:', mse_nn)
print('R-squared:', r2_nn)
# Out:
# Linear Regression Results:
# Mean Squared Error: 29426215.12215427
# R-squared: 0.8159322620265843
#
# Random Forest Regression Results:
# Mean Squared Error: 23265349.63155631
# R-squared: 0.8544698914874344
#
# Support Vector Regression Results:
# Mean Squared Error: 176662681.531211
# R-squared: -0.10506567150343504
#
# Neural Network Regression Results:
# Mean Squared Error: 331770371.2791457
# R-squared: -1.0752999158894854
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
rf_model.predict(pd.DataFrame({'age': [30], 'bmi': [80], 'smoker': [1]}))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# array([57344.9551987])

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


df=insurance
# Select the numerical columns for clustering
numerical_cols = ['age', 'bmi', 'children', 'charges']

# Create a new dataframe with only the numerical columns
X = df[numerical_cols]

# Perform K-means clustering with k=3
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)

# Get the cluster labels for each data point
labels = kmeans.labels_

# Add the cluster labels to the original dataframe
df['cluster'] = labels

# Visualize the clusters
plt.scatter(df['age'], df['charges'], c=df['cluster'], cmap='viridis')
plt.xlabel('Age')
plt.ylabel('Claim Amount')
plt.title('K-means Clustering of Insurance Data')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
